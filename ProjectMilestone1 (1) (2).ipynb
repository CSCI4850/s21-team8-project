# %% [markdown]
# GROUP 8: MILESTONE UPDATE PART 1

# %% [markdown]
# ![Screen Shot 2021-03-15 at 11.40.38 AM.png](attachment:e89e8743-d639-4580-adc8-ebbdd9bc8081.png)

# %% [markdown]
# 1. What deliverable goals established in the last milestone report were accomplished to the anticipated percentage?

# %% [markdown]
# <p>  The deliverable goal we established in our first meeting was to create a working chatbot and we have accomplished that.
#  We also found a nice data set in the right format, so we have started testing and training our bot.</p>

# %% [markdown]
# 2. What deliverable goals established in the last milestone
# report were were not accomplished to the anticipated percentage?

# %% [markdown]
# <p> Originally we had thought we were going to use a large data set that was in the wrong format, and we would have to go through and change it, but instead we found a better data set to use. So we did not accomplish editing our original data set to work for us. </p>

# %% [markdown]
# 3. What are the main deliverable goals to meet before the next milestone report, and who is working on them?

# %% [markdown]
# </p> Lorenzo is going to continue working on testing our chatbot with more data. Brooke is going to get started on research for our paper. Paula is going to work on code and find new functionalities to impliment. Jake is going to work with Lorenzo on testing the code and work with Brooke on the paper. David will also be working on testing the code with Lorenzo and Jake. .</p>

# %% [markdown]
# GROUP 8: MILESTONE UPDATE PART 2

# %% [markdown]
# ![update.PNG](attachment:c7b13dda-5cbf-4550-8f30-464fd842841a.PNG)

# %% [markdown]
# 1. What deliverable goals established in the last milestone report were accomplished to the anticipated percentage?

# %% [markdown]
# We accomplished work both on the research paper and on the code for our chatbot. Everyone has now download and tested the bot. Everyone now has a firm understanding of how the bot works and how we will move forward with testing.

# %% [markdown]
# 2. What deliverable goals established in the last milestone
# report were were not accomplished to the anticipated percentage?

# %% [markdown]
# We did not end up testing the bot with more data.

# %% [markdown]
# 3. What are the main deliverable goals to meet before the next milestone report, and who is working on them?

# %% [markdown]
# Jake is going to reformat a new data set that we found into the format that our bot requires. Brooke will continue to work on the research paper. Lorenzo, Paula, and David are going to create new conversation pieces for the bot to recognize and respond to so that conversation will be more fluid and natural. We are also going to steer the bot in the direction of a business bot. It will be "working" for a bakery, and will be able to answer any questions that a user may have about the bakery. In addition to questions about the business, the bot will also be able to respond to general conversational questions and statements.

# %% [markdown]
# GROUP 8: MILESTONE UPDATE PART 3

# %% [markdown]
# ![mar29milestone.PNG](attachment:46712324-9204-4903-a1f6-5fbb89434cd0.PNG)

# %% [markdown]
# 1. What deliverable goals established in the last milestone report were accomplished to the anticipated percentage?

# %% [markdown]
# We hit most of our goals from last week. We formatted the data set that we had found, made progress on the research paper, and added new conversational pieces to the intents.json file, as well.

# %% [markdown]
# 2. What deliverable goals established in the last milestone report were not accomplished to the anticipated percentage?

# %% [markdown]
# We did not miss any of our goals from the last milestone report.

# %% [markdown]
# 3. What are the main deliverable goals to meet before the next milestone report, and who is working on them?

# %% [markdown]
# Lorenzo and David are going to continue to train the bot in order to achieve higher accuracy. Paula is going to continue to add to the intents.json file in order to get smoother conversation. Brooke and Jake are going to be working on the research paper, focusing mainly on the methods and results section.

# %% [markdown]
# ![april5milestone.PNG](attachment:02755372-15f3-466b-9fc0-1664b0721518.PNG)

# %% [markdown]
# GROUP 8: MILESTONE UPDATE PART 4

# %% [markdown]
# 1. What deliverable goals established in the last milestone report were accomplished to the anticipated percentage?

# %% [markdown]
# We made good progress on our paper. Additionally, we made progress with training our bot. We have achieved 100% accuracy with the new training data.

# %% [markdown]
# 2. What deliverable goals established in the last milestone report were not accomplished to the anticipated percentage?

# %% [markdown]
# We did not finish the code to 100%. We realized that there were duplicates in our data sets, so we were getting poor results. Once this issue was realized, the data sets were modified, and new data is being added to it.

# %% [markdown]
# 3. What are the main deliverable goals to meet before the next milestone report, and who is working on them?

# %% [markdown]
# We are going to add an intents file to the main repo, so that everyone can add to it individually, then we can merge into one data set without duplicates later on. Lorenzo will modify new intents in order to make sure duplicates are not present. David will work on the intents file on the bakery side of the conversations that the bot will have. Paula suggested ideas about a front end for our chatbot, and will begin researching for that. Paula will also help Brooke and Jake with the paper.
